# %%
import pandas as pd

# %%
df=pd.read_csv("watson_healthcare_modified.csv")
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel  DailyRate  Department  \
# 0        1313919   41        No      Travel_Rarely       1102  Cardiology
# 1        1200302   49        No  Travel_Frequently        279   Maternity
# 2        1060315   37       Yes      Travel_Rarely       1373   Maternity
# 3        1272912   33        No  Travel_Frequently       1392   Maternity
# 4        1414939   27        No      Travel_Rarely        591   Maternity
# ...          ...  ...       ...                ...        ...         ...
# 1671     1117656   26       Yes      Travel_Rarely        471   Neurology
# 1672     1152327   46        No      Travel_Rarely       1125  Cardiology
# 1673     1812428   20        No      Travel_Rarely        959   Maternity
# 1674     1812429   39        No      Travel_Rarely        466   Neurology
# 1675     1152329   27        No      Travel_Rarely        511  Cardiology
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  ...  \
# ...

# %%
##To check the Null values in dataset
df.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# Shift                       0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()
# Out:
#          EmployeeID          Age    DailyRate  DistanceFromHome    Education  \
# count  1.676000e+03  1676.000000  1676.000000       1676.000000  1676.000000
# mean   1.456796e+06    36.866348   800.557876          9.221957     2.907518
# std    2.487486e+05     9.129126   401.594438          8.158118     1.025835
# min    1.025177e+06    18.000000   102.000000          1.000000     1.000000
# 25%    1.235832e+06    30.000000   465.000000          2.000000     2.000000
# 50%    1.464606e+06    36.000000   796.500000          7.000000     3.000000
# 75%    1.667992e+06    43.000000  1157.000000         14.000000     4.000000
# max    1.886378e+06    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count         1676.0              1676.000000  1676.000000     1676.000000
# mean             1.0                 2.714797    65.470167        2.724940
# ...

# %%
##To check how many duplicates in dataset
duplicate_count = df.duplicated().sum()
duplicate_count
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1676 entries, 0 to 1675
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                1676 non-null   int64
#  1   Age                       1676 non-null   int64
#  2   Attrition                 1676 non-null   object
#  3   BusinessTravel            1676 non-null   object
#  4   DailyRate                 1676 non-null   int64
#  5   Department                1676 non-null   object
#  6   DistanceFromHome          1676 non-null   int64
#  7   Education                 1676 non-null   int64
#  8   EducationField            1676 non-null   object
#  9   EmployeeCount             1676 non-null   int64
#  10  EnvironmentSatisfaction   1676 non-null   int64
#  11  Gender                    1676 non-null   object
#  12  HourlyRate                1676 non-null   int64
#  13  JobInvolvement            1676 non-null   int64
# ...

# %%
## dropping unwanted columns
df=df.drop(['EmployeeCount','StandardHours','Over18','Education'],axis=1)

# %%
df.select_dtypes(include=['object', 'category']).columns.tolist()
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
# Performing Exploratory Data Analysis

df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel  DailyRate  Department  \
# 0        1313919   41        No      Travel_Rarely       1102  Cardiology
# 1        1200302   49        No  Travel_Frequently        279   Maternity
# 2        1060315   37       Yes      Travel_Rarely       1373   Maternity
# 3        1272912   33        No  Travel_Frequently       1392   Maternity
# 4        1414939   27        No      Travel_Rarely        591   Maternity
# ...          ...  ...       ...                ...        ...         ...
# 1671     1117656   26       Yes      Travel_Rarely        471   Neurology
# 1672     1152327   46        No      Travel_Rarely       1125  Cardiology
# 1673     1812428   20        No      Travel_Rarely        959   Maternity
# 1674     1812429   39        No      Travel_Rarely        466   Neurology
# 1675     1152329   27        No      Travel_Rarely        511  Cardiology
#
#       DistanceFromHome    EducationField  EnvironmentSatisfaction  Gender  \
# ...

# %%
## UNIVARIATE ANALYSIS

# %%
from UnivariateFile import UnivariateClass as uv
Quan,Qual=uv.QuanQual(df)
Quan
# Out:
# ['EmployeeID',
#  'Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'Shift',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
df[Quan].isnull().sum()
df[Quan].drop('EmployeeID',axis=1)
# Out:
#       Age  DailyRate  DistanceFromHome  EnvironmentSatisfaction  HourlyRate  \
# 0      41       1102                 1                        2          94
# 1      49        279                 8                        3          61
# 2      37       1373                 2                        4          92
# 3      33       1392                 3                        4          56
# 4      27        591                 2                        1          40
# ...   ...        ...               ...                      ...         ...
# 1671   26        471                24                        3          66
# 1672   46       1125                10                        3          94
# 1673   20        959                 1                        4          83
# 1674   39        466                 1                        4          65
# 1675   27        511                 2                        1          89
#
# ...

# %%
descriptive=uv.univariate_descriptive(df,Quan)

descriptive[Quan].drop('EmployeeID',axis=1)
# Out:
#                      Age      DailyRate DistanceFromHome  \
# Mean           36.866348     800.557876         9.221957
# Median              36.0          796.5              7.0
# Mode                  35            691                2
# Q1-25%              30.0          465.0              2.0
# Q2-50%              36.0          796.5              7.0
# Q3-75%              43.0         1157.0             14.0
# 99%                 58.0        1482.75             29.0
# Q4-100%             60.0         1499.0             29.0
# IQR                 13.0          692.0             12.0
# 1.5rule             19.5         1038.0             18.0
# Lesser_range        10.5         -573.0            -16.0
# Greater_range       62.5         2195.0             32.0
# Min                   18            102                1
# Max                   60           1499               29
# kurtosis        -0.42809      -1.201299         -0.25171
# ...

# %%
## Finding the outliers
lesser_outlier,greater_outlier=uv.Identify_Outliers(descriptive,Quan)
lesser_outlier,greater_outlier
# Out:
# (['TrainingTimesLastYear'],
#  ['MonthlyIncome',
#   'NumCompaniesWorked',
#   'PerformanceRating',
#   'Shift',
#   'TotalWorkingYears',
#   'TrainingTimesLastYear',
#   'YearsAtCompany',
#   'YearsInCurrentRole',
#   'YearsSinceLastPromotion',
#   'YearsWithCurrManager'])

# %%
#replacing outliers with outlier range values
uv.replace_outliers(df,descriptive,lesser_outlier,greater_outlier)
# Out:
# /Users/Max/Desktop/AI - Mohana/ML Capstone Project/UnivariateFile.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnname][dataset[columnname]<descriptive[columnname]["Lesser_range"]]=descriptive[columnname]["Lesser_range"]
# /Users/Max/Desktop/AI - Mohana/ML Capstone Project/UnivariateFile.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnname][dataset[columnname]>descriptive[columnname]["Greater_range"]]=descriptive[columnname]["Greater_range"]
# /Users/Max/Desktop/AI - Mohana/ML Capstone Project/UnivariateFile.py:59: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel  DailyRate  Department  \
# 0        1313919   41        No      Travel_Rarely       1102  Cardiology
# 1        1200302   49        No  Travel_Frequently        279   Maternity
# 2        1060315   37       Yes      Travel_Rarely       1373   Maternity
# 3        1272912   33        No  Travel_Frequently       1392   Maternity
# 4        1414939   27        No      Travel_Rarely        591   Maternity
# ...          ...  ...       ...                ...        ...         ...
# 1671     1117656   26       Yes      Travel_Rarely        471   Neurology
# 1672     1152327   46        No      Travel_Rarely       1125  Cardiology
# 1673     1812428   20        No      Travel_Rarely        959   Maternity
# 1674     1812429   39        No      Travel_Rarely        466   Neurology
# 1675     1152329   27        No      Travel_Rarely        511  Cardiology
#
#       DistanceFromHome    EducationField  EnvironmentSatisfaction  Gender  \
# ...

# %%
## validating whether the outliers are replaced

descriptive=uv.univariate_descriptive(df,Quan)

lesser_outlier,greater_outlier=uv.Identify_Outliers(descriptive,Quan)
lesser_outlier,greater_outlier
# Out:
# ([], [])

# %%
## Frequency, Relative_frequency, cummulative relative frequency##

freqtable=uv.freqtable(df,"TotalWorkingYears")
freqtable
# Out:
#     Uniq_values  Frequency  Rel_Frequency  Cum_Frequency
# 0          10.0        233       7.766667       7.766667
# 1           6.0        140       4.666667      12.433333
# 2           8.0        123       4.100000      16.533333
# 3           9.0        108       3.600000      20.133333
# 4           5.0        100       3.333333      23.466667
# 5           1.0         94       3.133333      26.600000
# 6           7.0         88       2.933333      29.533333
# 7          28.5         75       2.500000      32.033333
# 8           4.0         70       2.333333      34.366667
# 9          12.0         51       1.700000      36.066667
# 10          3.0         50       1.666667      37.733333
# 11         15.0         47       1.566667      39.300000
# 12         16.0         40       1.333333      40.633333
# 13         17.0         40       1.333333      41.966667
# 14         21.0         39       1.300000      43.266667
# ...

# %%
Qual
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
## Converting Qual into Numerical columns

#to convert non numerical into numerical data
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse=False, drop='first', dtype=int)
encoded_array = encoder.fit_transform(df[['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']])

# %%
#  Get clean names for the new columns and create a DataFrame
columns_to_encode = ['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']
encoded_column_names = encoder.get_feature_names(columns_to_encode)
encoded_df = pd.DataFrame(encoded_array, columns=encoded_column_names)

# Merge back into the original dataset and drop the old raw text columns
# We use .concat() along axis=1 to join them side-by-side
final_df = pd.concat([df, encoded_df], axis=1).drop(columns=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime'])
final_df
# Out:
#       EmployeeID  Age Attrition  DailyRate  DistanceFromHome  \
# 0        1313919   41        No       1102                 1
# 1        1200302   49        No        279                 8
# 2        1060315   37       Yes       1373                 2
# 3        1272912   33        No       1392                 3
# 4        1414939   27        No        591                 2
# ...          ...  ...       ...        ...               ...
# 1671     1117656   26       Yes        471                24
# 1672     1152327   46        No       1125                10
# 1673     1812428   20        No        959                 1
# 1674     1812429   39        No        466                 1
# 1675     1152329   27        No        511                 2
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                           2          94               3         2
# 1                           3          61               2         2
# ...

# %%
'''from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)'''

# %%
'''from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)'''

# %%
'''scy=StandardScaler()
y_train=sc.fit_transform(y_train)
y_test=sc.transform(y_test)'''

# %%
import seaborn as sns
sns.distplot(final_df["MonthlyIncome"])
# Out:
# /var/folders/zw/5lnmsxzx7n739450_qfkn30c0000gn/T/ipykernel_79199/774883133.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(final_df["MonthlyIncome"])
# <Axes: xlabel='MonthlyIncome', ylabel='Density'>

# %%
def get_pdf_probability(sample,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(sample,kde=True,kde_kws={'color':'blue'},color='Green')
    ##kde- kernel density
    ##densiy- color in blue
    ##Curve color in Green
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    ## v - for vertical line
    
    ##Calculate parameters
    samplemean=sample.mean()
    samplestd=sample.std()
    print(f'Mean-{samplemean:.2f} , Standard Deviation-{samplestd:.2f}')
    
    
    ##define distribution
    dist=norm(samplemean,samplestd)
    
    ##sample probablities of range of outcomes
    values=[value for value in range(startrange,endrange)]
    probablities=[dist.pdf(value) for value in values]
    prob=sum(probablities)
    print("The area between the range({},{}):{}".format(startrange,endrange,prob))
    return prob

# %%
##PDF - Probablity Distribution Function
get_pdf_probability(final_df["MonthlyIncome"],3000,6000)
# Out:
# /var/folders/zw/5lnmsxzx7n739450_qfkn30c0000gn/T/ipykernel_79199/2260445709.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(sample,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean-6371.12 , Standard Deviation-4365.46
# The area between the range(3000,6000):0.24612351995920018
# 0.24612351995920018

# %%
##CDF - Cumulative Distribution Function

from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(final_df["MonthlyIncome"])
ecdf(3000)
# Out:
# 0.26610978520286394

# %%
##converting normal distribution to standard normal distribution
## There is no predefined functionality for this, so our own function is required to convert

# %%
def stdNDgraph(dataset):
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    ##data=dataset.values.flatten().tolist()
    data=[j for j in dataset]
    z_score=[((i-mean)/std) for i in data]

    sns.histplot(z_score,kde=True)

# %%
stdNDgraph(final_df["MonthlyIncome"])

# %%
## BIVARIATE ANALYSIS

# %%
# Covariance of dataset
final_df.cov()
# Out:
#                                     EmployeeID           Age      DailyRate  \
# EmployeeID                        6.187588e+10 -88637.520328 -255576.118755
# Age                              -8.863752e+04     83.340933       5.283561
# DailyRate                        -2.555761e+05      5.283561  161278.092768
# DistanceFromHome                 -6.422429e+04     -0.750616     -30.229570
# EnvironmentSatisfaction          -1.618920e+03      0.089621       4.680994
# HourlyRate                        3.505256e+01      6.396010     220.153668
# JobInvolvement                   -1.109746e+04      0.222917      16.881302
# JobLevel                         -8.332372e+03      5.268638       4.026578
# JobSatisfaction                  -2.030018e+03     -0.159725      14.238418
# MonthlyIncome                    -3.135504e+07  20460.344157   20287.427636
# MonthlyRate                      -1.746565e+07   1683.821141  -92347.445618
# ...

# %%
##Based on the above result, there is a large positive covariance exists between Monthly Rate and Attrition.
## So Attrition rate increases when MonthlyRate increases.

# %%
#Q1) How many nurses got sacked under the age of 45?

nurses_count = df[ (df['Age'] <= 45) & (df['Attrition'] == 'Yes')]
nurses_count.shape[0]
# Out:
# 183

# %%
#what is the average age for Attrition

average_age = df[df['Attrition'] == 'Yes']['Age'].mean()
average_age
# Out:
# 30.899497487437184

# %%
#Which department have more number of attrition and least number of attrition
dept_count = df[df['Attrition'] == 'Yes']['Department'].value_counts()
dept_count[dept_count == dept_count.max()]
## Maternity dept has more number of attrition and Neurology dept has least number of attrition
# Out:
# Maternity    98
# Name: Department, dtype: int64

# %%
# Is there any correlation between attrition and RelationshipSatisfaction
correlation = final_df['Attrition'].corr(df['RelationshipSatisfaction'])
correlation
#Weak relationship
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Is there any correlation between attrition and RelationshipSatisfaction
# ----> 2 correlation = final_df['Attrition'].corr(df['RelationshipSatisfaction'])
#       3 correlation
#       4 #Weak relationship
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:2327, in Series.corr(self, other, method, min_periods)
#    2324     return np.nan
#    2326 if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2327     return nanops.nancorr(
#    2328         this.values, other.values, method=method, min_periods=min_periods
#    2329     )
#    2331 raise ValueError(
#    2332     "method must be either 'pearson', "
#    2333     "'spearman', 'kendall', or a callable, "
#    2334     f"'{method}' was supplied"
#    2335 )
#
# ...

# %%
# Is there any correlation between attrition and PerformanceRating
correlation = final_df['Attrition'].corr(df['PerformanceRating'])
correlation 
#Weak relationship
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Is there any correlation between attrition and PerformanceRating
# ----> 2 correlation = final_df['Attrition'].corr(df['PerformanceRating'])
#       3 correlation
#       4 #Weak relationship
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:2327, in Series.corr(self, other, method, min_periods)
#    2324     return np.nan
#    2326 if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2327     return nanops.nancorr(
#    2328         this.values, other.values, method=method, min_periods=min_periods
#    2329     )
#    2331 raise ValueError(
#    2332     "method must be either 'pearson', "
#    2333     "'spearman', 'kendall', or a callable, "
#    2334     f"'{method}' was supplied"
#    2335 )
#
# ...

# %%
#Relationship between attrition and entire dataset
all_correlations = final_df.corr()['Attrition'].sort_values(ascending=False)
all_correlations
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3080, in Index.get_loc(self, key, method, tolerance)
#    3079 try:
# -> 3080     return self._engine.get_loc(casted_key)
#    3081 except KeyError as err:
#
# File pandas/_libs/index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:4554, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:4562, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Attrition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
# ...

# %%
#To find multicollinearity in dataset

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor ##import the function variance_inflation_factor

def cal_vif(X):
    
    ##calculate VIF
    vif=pd.DataFrame()  ## Creating new dataframe

    vif["variables"]=X.columns ## Converting column names as column values
    
    ## for i in range(X.shape[1])--> shape[1]-gives the number of columns and loop executes until number of columns
    ## for each column index and row values , VIF is calulated using variance_inflation_factor(X.values,i)

    vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    return vif

# %%
from UnivariateFile import UnivariateClass as uv
Quan,Qual=uv.QuanQual(df)
vif=cal_vif(df[Quan])
vif[vif['VIF']>5]
# Out:
#             variables         VIF
# 7            JobLevel   10.458651
# 9       MonthlyIncome   10.107694
# 13  PerformanceRating  155.158813
# 19     YearsAtCompany    5.646249

# %%
## PerformanceRating,JobLevel,MonthlyIncome variables,YearsAtCompany are highly correlated which means Multicollinearity exists

# %%
#####  Ways to remove Multicollinearity
""""
1. Remove Highly Correlated Features using correlation matrix df.corr():
If two variables are highly correlated and have similar information then keep one remove the other feature.

2. Using VIF:
If, VIF > 5 → high correlation or VIF > 10 → severe multicollinearity then remove features with highest VIF.

##vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]

3.Using Principal Component Analysis:
PCA transforms correlated variables into uncorrelated components. This works well only if many correlated features 
exist and interpretability is less important.

##from sklearn.decomposition import PCA

4. Using Ridge Regression:
To reduce coefficient instability caused by multicollinearity by adding L2 penalty to the loss function.
It keeps all the features and reduces coefficient variance and does NOT make coefficients exactly zero.

5. Using Lasso Regression:
This can automatically remove less important correlated variables. Some coefficients become exactly zero.

6. Feature Engineering / Combining Variables:
Combine related variables into one.

###Example:
ssc_p
hsc_p

Create:
school_total_marks = ssc_p + hsc_p

7. Collect More Data:
Sometimes multicollinearity becomes less severe with larger datasets.So this way is useful only when sample size 
is too small and many similar features exist

8. Domain Knowledge Based Selection:
Choosing the most meaningful feature based on business understanding.

###Example:
keep mba_p
remove degree_p
because both represent similar information.
""""
# Out:
#   Cell In[42], line 45
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
final_df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Attrition', 'DailyRate', 'DistanceFromHome',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'Shift', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'Department_Maternity', 'Department_Neurology',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Male',
#        'JobRole_Administrative', 'JobRole_Nurse', 'JobRole_Other',
#        'JobRole_Therapist', 'MaritalStatus_Married', 'MaritalStatus_Single',
# ...

# %%
independent=final_df.drop('Attrition',axis=1)

# %%
dependent=final_df['Attrition']

# %%
x=independent
y=dependent

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=0)
rf.fit(x,y)

importance = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf.feature_importances_
}).sort_values('Importance', ascending=False)

print(importance)
# Out:
#                              Feature  Importance
# 39                      OverTime_Yes    0.097012
# 1                                Age    0.077785
# 9                      MonthlyIncome    0.076437
# 16                 TotalWorkingYears    0.058112
# 0                         EmployeeID    0.056506
# 3                   DistanceFromHome    0.044102
# 2                          DailyRate    0.041043
# 10                       MonthlyRate    0.039956
# 19                    YearsAtCompany    0.038974
# 5                         HourlyRate    0.035434
# 11                NumCompaniesWorked    0.029407
# 4            EnvironmentSatisfaction    0.029091
# 6                     JobInvolvement    0.028332
# 7                           JobLevel    0.027695
# 15                             Shift    0.026694
# 22              YearsWithCurrManager    0.026689
# 12                 PercentSalaryHike    0.026148
# 20                YearsInCurrentRole    0.025498
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(criterion='gini',max_features='sqrt',splitter='best',random_state=0)
dt.fit(x,y)

importance = pd.DataFrame({
    'Feature': x.columns,
    'Importance': dt.feature_importances_
}).sort_values('Importance', ascending=False)

print(importance)
# Out:
#                              Feature  Importance
# 39                      OverTime_Yes    0.130461
# 9                      MonthlyIncome    0.126920
# 1                                Age    0.073893
# 0                         EmployeeID    0.066365
# 16                 TotalWorkingYears    0.052686
# 3                   DistanceFromHome    0.049432
# 15                             Shift    0.048762
# 4            EnvironmentSatisfaction    0.047482
# 19                    YearsAtCompany    0.043160
# 20                YearsInCurrentRole    0.034845
# 6                     JobInvolvement    0.034208
# 5                         HourlyRate    0.030433
# 17             TrainingTimesLastYear    0.027991
# 34                     JobRole_Nurse    0.022957
# 18                   WorkLifeBalance    0.022575
# 2                          DailyRate    0.021694
# 10                       MonthlyRate    0.018086
# 11                NumCompaniesWorked    0.017981
# ...

# %%
## Based on the FeatureImportance executed above on dataset, we conclude to remove  "PerformanceRating" variable

# %%
df=df.drop('PerformanceRating',axis=1)
final_df=final_df.drop('PerformanceRating',axis=1)

# %%
from UnivariateFile import UnivariateClass as uv
Quan,Qual=uv.QuanQual(df)
vif=cal_vif(df[Quan])
vif[vif['VIF']>5]
# Out:
#                    variables        VIF
# 0                 EmployeeID  26.908779
# 1                        Age  32.127852
# 4    EnvironmentSatisfaction   6.897198
# 5                 HourlyRate  10.864995
# 6             JobInvolvement  14.290658
# 7                   JobLevel  46.035068
# 8            JobSatisfaction   6.909429
# 9              MonthlyIncome  31.531632
# 12         PercentSalaryHike  16.322754
# 13  RelationshipSatisfaction   7.262333
# 15         TotalWorkingYears  15.492088
# 16     TrainingTimesLastYear   7.557964
# 17           WorkLifeBalance  15.204517
# 18            YearsAtCompany  14.644414
# 19        YearsInCurrentRole   7.609386
# 21      YearsWithCurrManager   7.640540

# %%
'''Scenario B: If Accuracy is Important
(e.g., You just want a system that flags high-risk employees with the absolute highest precision, 
and nobody cares about coefficients).

The Models to Use:
Random Forest Classifier: Handles high-dimensional, correlated variables seamlessly. It will maintain top-tier accuracy without 
crashing or underperforming due to the multicollinearity.

XGBoost / LightGBM: Highly optimized gradient boosting algorithms. 
They will squeeze out every bit of predictive power from your features, leveraging the overlap between JobLevel and MonthlyIncome 
to minimize classification errors.

'''
'''Scenario A: If Interpretability is Important
(e.g., HR needs to know exactly why employees leave so they can change company policy).

The Models to Use:Logistic Regression: The gold standard for interpretability. It outputs odds ratios 
(e.g., "For every step increase in Job Level, an employee is 40% less likely to leave"). By dropping the high VIF features first, 
your odds ratios become completely stable and trustworthy.

Decision Trees (Single Tree): Extremely easy to visualize as a flowchart. 
Because it is a single tree, you can visually trace exactly how the model classifies an individual.

'''

# %%
# =====================================================================
# THE PCA PIPELINE FOR MULTICOLLINEARITY REMOVAL
# =====================================================================

# Step 1: Scale the features (PCA fails completely without standardization)


from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# Step 2: Fit PCA
# We choose  components to compress the highly correlated variables
from sklearn.decomposition import PCA
pca = PCA(n_components=28)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)
# Step 3: Convert the PCA results back into a clean Pandas DataFrame
pca_columns = [f'PC_{i+1}' for i in range(x_train.shape[1])]
df_pca = pd.DataFrame(x_train, columns=pca_columns)

print("\n--- Transformed PCA Data (First 5 Rows) ---")
print(df_pca.head())
# Out:
# --- Transformed PCA Data (First 5 Rows) ---
#        PC_1      PC_2      PC_3      PC_4      PC_5      PC_6      PC_7  \
# 0  0.012237  1.413238  1.752835 -0.796832  0.558078 -1.081575  0.276526
# 1  1.038567  0.634457 -1.524155  0.966450 -1.146827 -0.370496  1.597941
# 2  1.027715 -2.749115 -0.553649 -0.755135  0.885122 -0.846167 -2.121767
# 3  0.195663 -1.650300 -0.066597  0.643230  0.013723 -0.433067  0.223862
# 4 -0.216468  0.036210 -1.869966  0.474080 -1.745762 -0.783055  1.044521
#
#        PC_8      PC_9     PC_10  ...     PC_19     PC_20     PC_21     PC_22  \
# 0  2.660914 -1.097726 -1.483533  ... -2.336194  0.321800 -0.167291 -1.021915
# 1  0.811205 -0.244638 -1.657804  ... -0.395846 -0.678546 -0.351824 -1.193141
# 2  1.195097  0.686416 -1.326010  ... -0.295202  0.348992  0.104942  0.645278
# 3 -1.543018  0.856883  0.090385  ...  0.332202  0.056767  0.264940 -0.799563
# 4 -0.823512 -2.498552 -0.743374  ...  0.067804  0.206712  0.524470 -0.900547
#
# ...

# %%
# =====================================================================
# VERIFYING THE NEW NEW VIF SCORES (MUST BE EXACTLY 1.0)
# =====================================================================

from UnivariateFile import UnivariateClass as uv
vif=cal_vif(df_pca)
#vif[vif['VIF']>5]
vif
# Out:
#    variables  VIF
# 0       PC_1  1.0
# 1       PC_2  1.0
# 2       PC_3  1.0
# 3       PC_4  1.0
# 4       PC_5  1.0
# 5       PC_6  1.0
# 6       PC_7  1.0
# 7       PC_8  1.0
# 8       PC_9  1.0
# 9      PC_10  1.0
# 10     PC_11  1.0
# 11     PC_12  1.0
# 12     PC_13  1.0
# 13     PC_14  1.0
# 14     PC_15  1.0
# 15     PC_16  1.0
# 16     PC_17  1.0
# 17     PC_18  1.0
# 18     PC_19  1.0
# 19     PC_20  1.0
# 20     PC_21  1.0
# 21     PC_22  1.0
# 22     PC_23  1.0
# 23     PC_24  1.0
# 24     PC_25  1.0
# 25     PC_26  1.0
# 26     PC_27  1.0
# 27     PC_28  1.0

# %%
## Train the model using LogisticRegression
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(x_train,y_train)

y_pred=classifier.predict(x_test)
    
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
    
from sklearn.metrics import classification_report
report=classification_report(y_test,y_pred)
    
from sklearn.metrics import accuracy_score
Accuracy=accuracy_score(y_test,y_pred)

# %%
#print (Accuracy,report,cm) ## n=27
# Out:
# 0.9184890656063618               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       451
#            1       0.63      0.52      0.57        52
#
#     accuracy                           0.92       503
#    macro avg       0.79      0.74      0.76       503
# weighted avg       0.91      0.92      0.92       503
#  [[435  16]
#  [ 25  27]]

# %%
##print (Accuracy,report,cm) ## n=25
# Out:
# 0.9284294234592445               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       433
#            1       0.81      0.63      0.71        70
#
#     accuracy                           0.93       503
#    macro avg       0.88      0.80      0.83       503
# weighted avg       0.92      0.93      0.92       503
#  [[423  10]
#  [ 26  44]]

# %%
#print (Accuracy,report,cm) ## n=26
# Out:
# 0.9363817097415507               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       443
#            1       0.91      0.52      0.66        60
#
#     accuracy                           0.94       503
#    macro avg       0.92      0.75      0.81       503
# weighted avg       0.94      0.94      0.93       503
#  [[440   3]
#  [ 29  31]]

# %%
##print (Accuracy,report,cm) ## n=28
# Out:
# 0.9383697813121272               precision    recall  f1-score   support
#
#           No       0.95      0.98      0.96       432
#          Yes       0.86      0.68      0.76        71
#
#     accuracy                           0.94       503
#    macro avg       0.90      0.83      0.86       503
# weighted avg       0.94      0.94      0.94       503
#  [[424   8]
#  [ 23  48]]

# %%
from sklearn.model_selection import GridSearchCV

param_grid=[{'penalty': ['l1', 'l2', 'elasticnet', None]},
         {'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']}]

grid=GridSearchCV(LogisticRegression(),param_grid,refit=True,cv=5,n_jobs=-1,verbose=3,scoring='f1_weighted')

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.4s finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=-1,
# ...

# %%
re=grid.cv_results_
print(re)
#grid.coef_
# Out:
# {'mean_fit_time': array([0.0012713 , 0.02423515, 0.00114527, 0.00054855, 0.01607914,
#        0.01338458, 0.2078187 , 0.00071807, 0.04386659, 0.11668119]), 'std_fit_time': array([4.30001280e-04, 6.86397388e-03, 9.05545195e-04, 9.48092577e-05,
#        1.62020669e-03, 1.95598070e-03, 1.24667130e-01, 9.54474352e-05,
#        1.23947835e-02, 4.94372722e-02]), 'mean_score_time': array([0.        , 0.00518184, 0.        , 0.        , 0.00539465,
#        0.02804408, 0.00792108, 0.        , 0.00774021, 0.02148252]), 'std_score_time': array([0.        , 0.00070913, 0.        , 0.        , 0.00133623,
#        0.04452388, 0.00565718, 0.        , 0.0062335 , 0.03493452]), 'param_penalty': masked_array(data=['l1', 'l2', 'elasticnet', None, --, --, --, --, --, --],
#              mask=[False, False, False, False,  True,  True,  True,  True,
#                     True,  True],
#        fill_value='?',
# ...

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[424   8]
#  [ 23  48]]

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.95      0.98      0.96       432
#          Yes       0.86      0.68      0.76        71
#
#     accuracy                           0.94       503
#    macro avg       0.90      0.83      0.86       503
# weighted avg       0.94      0.94      0.94       503

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,y_pred,average='weighted')
print('The f1_macro value for best param:{}'.format(grid.best_params_), f1_macro)
# Out:
# The f1_macro value for best param:{'penalty': 'l2'} 0.9352560565766135

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
# Out:
# 0.9241001564945227

# %%
import pickle 
pickle.dump(grid,open('CapstoneProjectLogRegGrid.pkl','wb'))
